# %% [markdown]
# # Cerno Project

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow==2.5.0
# Out:
# Requirement already satisfied: numpy in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (1.19.5)
# Requirement already satisfied: pandas in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (1.3.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: matplotlib in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from matplotlib) (1.19.5)
# Requirement already satisfied: six in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: scikit-learn in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from scikit-learn) (1.7.1)
# Collecting tensorflow==2.5.0
#   Using cached tensorflow-2.5.0-cp39-cp39-win_amd64.whl (422.6 MB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1-cp39-cp39-win_amd64.whl
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorflow==2.5.0) (3.18.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorflow==2.5.0) (1.15.0)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp39-cp39-win_amd64.whl (2.9 MB)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorflow==2.5.0) (1.19.5)
# Requirement already satisfied: wheel~=0.35 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorflow==2.5.0) (0.37.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (58.0.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\thomas\anaconda3\envs\cerno_project\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.1.1)
# Installing collected packages: markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-0.14.0 astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 opt-einsum-3.3.0 tensorboard-2.6.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
from datetime import datetime

from sklearn.model_selection import train_test_split

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.preprocessing import StandardScaler

from sklearn.pipeline import Pipeline

from pandas.plotting import scatter_matrix

# %% [markdown]
# **Data Cleaning**

# %%
data_dir = 'C:/Users/Thomas/OneDrive/Desktop/DataPaper/'

users = [user for user in os.listdir(data_dir) if user.startswith('user_')]
print(users)

for user in users:
    
    sleep_path = os.path.join(data_dir, user, 'sleep.csv')
    # Index (unnamed), 'In Bed Date', 'In Bed Time', 'Out Bed Date', 'Out Bed Time'
    sleep_df = pd.read_csv(sleep_path, index_col=0, usecols=[0,1,2,3,4])
    display(sleep_df)
    
    signals_path = os.path.join(data_dir, user, 'Actigraph.csv')
    # Index (unnamed), 'Axis1', 'Axis2', 'Axis3', 'Steps', 'HR'
    signals_df = pd.read_csv(signals_path, index_col=[0], usecols=[0,1,2,3,4,5])
    display(signals_df)
   
    # Data cleaning
    if sleep_df.empty or sleep_df.isnull().any().any() or signals_df.empty or signals_df.isnull().any().any():
        print(user)
        users.remove(user)


print(len(users))
# Out:
# ['user_1', 'user_10', 'user_11', 'user_12', 'user_13', 'user_14', 'user_15', 'user_16', 'user_17', 'user_18', 'user_19', 'user_2', 'user_20', 'user_21', 'user_22', 'user_3', 'user_4', 'user_5', 'user_6', 'user_7', 'user_8', 'user_9']
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:46             2        03:31
# 1            2       03:57             2        07:30
#        Axis1  Axis2  Axis3  Steps     HR
# 82         0      0      0      0   68.0
# 83        11      4      7      1   68.0
# 84         0     21     10      0   68.0
# 85         0      1     24      0   68.0
# 86        34     14     63      1  154.0
# ...      ...    ...    ...    ...    ...
# 84985     31      0     31      1  119.0
# 84986     34      0     17      0  121.0
# 84987      7      4      3      0  123.0
# 84988     12     50     13      0  124.0
# 84995     84     27    237      1  125.0
#
# [67936 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       02:40             2        08:09
#        Axis1  Axis2  Axis3  Steps     HR
# 250        0      0      8      0  171.0
# 251       43     43     64      0  171.0
# 252       16      2     53      1  171.0
# 285        0      0      0      0   84.0
# 286        0      0      0      0   84.0
# ...      ...    ...    ...    ...    ...
# 87584     15     22     29      0  100.0
# 87585    108    106     55      1  100.0
# 87586     35     60    100      1  100.0
# 87587     93     63    145      1  100.0
# 87588    152    196     74      0  100.0
#
# [58616 rows x 5 columns]
# Empty DataFrame
# Columns: [In Bed Date, In Bed Time, Out Bed Date, Out Bed Time]
# Index: []
#        Axis1  Axis2  Axis3  Steps     HR
# 39        53     61    106      1  213.0
# 40        34      0     21      0  213.0
# 41         0      0     35      0  213.0
# 42         0      0      4      0  213.0
# 43         0      0      0      0  213.0
# ...      ...    ...    ...    ...    ...
# 87085     67     31     76      0   91.0
# 87086     75    113     80      0   91.0
# 87087     45    101     66      1   91.0
# 87088    188    166    271      0   91.0
# 87089     14    198    159      0   91.0
#
# [68362 rows x 5 columns]
# user_11
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            1       23:41             1        05:04
#        Axis1  Axis2  Axis3  Steps    HR
# 8         55     39    133      0  93.0
# 9          0      0     33      0  93.0
# 28         0      0      0      0  15.0
# 29         4      1      7      1  94.0
# 30        58     42     31      1  94.0
# ...      ...    ...    ...    ...   ...
# 84208      0      0      0      0  90.0
# 84209      0      0      0      0  90.0
# 84210      0      0      0      0  90.0
# 84211      0      0      0      0  90.0
# 84212      0      0      0      0  90.0
#
# [67350 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:08             2        07:00
#        Axis1  Axis2  Axis3  Steps     HR
# 129        0      0      0      0  100.0
# 130        0      0      0      0  101.0
# 131        0      0      0      0  101.0
# 132        0      0      0      0  101.0
# 133        0      0      0      0  101.0
# ...      ...    ...    ...    ...    ...
# 85327      0      0      0      0  122.0
# 85328      0      0      0      0  122.0
# 85329      0      0      0      0  122.0
# 85330      0      0      0      0  122.0
# 85331      0      0      0      0  122.0
#
# [67995 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       01:15             2        05:39
#        Axis1  Axis2  Axis3  Steps     HR
# 28        99     32     94      0  207.0
# 29         2     54    131      1  207.0
# 30       114     95     68      0  207.0
# 31        57     30     88      0  207.0
# 32        72    105    112      1  207.0
# ...      ...    ...    ...    ...    ...
# 91795      0      0      0      0  145.0
# 91796      0      0      0      0  145.0
# 91797      0      0      0      0  146.0
# 91798      0      0      0      0  152.0
# 91799      0      0      0      0  157.0
#
# [71045 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:22             2        07:58
#        Axis1  Axis2  Axis3  Steps     HR
# 218        2     35     39      0   30.0
# 219       31    119     68      1   30.0
# 220       27     46     73      0   30.0
# 221       14     48     30      0   30.0
# 222       19     73     10      1   30.0
# ...      ...    ...    ...    ...    ...
# 92395      0      0      0      0  126.0
# 92396      0      0      0      0  122.0
# 92397      0      0      0      0  121.0
# 92398      0      0      0      0  118.0
# 92399      0      0      0      0  122.0
#
# [69850 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:44             2        06:36
#        Axis1  Axis2  Axis3  Steps     HR
# 10        14      0     58      1  228.0
# 11         0      0     19      0  215.0
# 12        64    116     50      0  215.0
# 13        10    208    133      1  215.0
# 14        36     56     78      0  215.0
# ...      ...    ...    ...    ...    ...
# 91823      0      0      0      0  149.0
# 91824      0      0      0      0  151.0
# 91825      0      0      0      0  151.0
# 91826      0      0      0      0  153.0
# 91827      0      0      0      0  152.0
#
# [68351 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:55             2        06:53
#        Axis1  Axis2  Axis3  Steps     HR
# 90        83      0     26      0  227.0
# 91        83     64     26      0  227.0
# 92        45     12     22      1  227.0
# 93         8      0      4      0  227.0
# 94         0      0      0      0  180.0
# ...      ...    ...    ...    ...    ...
# 86374      0      0      0      0   87.0
# 86375      0      0      0      0   87.0
# 86376      0      0      0      0   87.0
# 86377      0      0      0      0   87.0
# 86378      0      0      0      0   87.0
#
# [65911 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            1       22:56             1        06:35
#        Axis1  Axis2  Axis3  Steps     HR
# 69        87    257    110      1   79.0
# 70        17    211     89      0   79.0
# 71        28     55      0      1   79.0
# 72         0     23      0      0   77.0
# 73         0      0      0      0   74.0
# ...      ...    ...    ...    ...    ...
# 85575      0      0      0      0  100.0
# 85576      0      0      0      0  100.0
# 85577      0      0      0      0  100.0
# 85578      0      0      0      0  100.0
# 85579      0      0      0      0  100.0
#
# [68326 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:50             2        06:22
#        Axis1  Axis2  Axis3  Steps     HR
# 201       19    120     72      1  136.0
# 202       89    188    113      1  136.0
# 203      107     30     94      1   94.0
# 204      127     65    120      1   94.0
# 205       68    185     65      1   94.0
# ...      ...    ...    ...    ...    ...
# 85509     15    104     71      1   86.0
# 85510      0     22     20      0   86.0
# 85511      0      0      0      0   86.0
# 85512      0      0      0      0   86.0
# 85513      0      0      0      0   86.0
#
# [60862 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       01:03             2        08:19
#        Axis1  Axis2  Axis3  Steps     HR
# 23       275     86     67      1   72.0
# 24        93    112     45      1   69.0
# 25        69     39     61      0   68.0
# 26        66     86    140      1   68.0
# 27        50     44     38      0   69.0
# ...      ...    ...    ...    ...    ...
# 84913      0      0      0      0  102.0
# 84914      0      0      0      0  102.0
# 84915      0      0      0      0  102.0
# 84916      0      0      0      0  102.0
# 84917      0      0      0      0  102.0
#
# [64740 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       02:19             2        07:16
#        Axis1  Axis2  Axis3  Steps     HR
# 23        19      0      0      0   98.0
# 24        49      0      5      1   97.0
# 25       108     34      3      0  153.0
# 26        45      5      0      1  166.0
# 27        99      0     46      0  166.0
# ...      ...    ...    ...    ...    ...
# 83208      2      0      9      0  149.0
# 83209      4      0     24      0  149.0
# 83210     13      0     42      1  149.0
# 83211      0      5      0      0  149.0
# 83212      0      0      0      0  142.0
#
# [67186 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       01:06             2        07:04
#        Axis1  Axis2  Axis3  Steps    HR
# 9          0      0      0      0  70.0
# 10         0      0      0      0  71.0
# 11         0      0      0      0  71.0
# 12         0      0      0      0  71.0
# 13         0      0      0      0  71.0
# ...      ...    ...    ...    ...   ...
# 84411     90    115     80      0  72.0
# 84412     33     49     28      1  72.0
# 84413     32     25     34      0  72.0
# 84414     59     28    188      1  72.0
# 84415     70     22    158      0  72.0
#
# [67874 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            1       22:29             1        05:52
#        Axis1  Axis2  Axis3  Steps    HR
# 251       14     13    134      0  93.0
# 252       34      0     59      1  93.0
# 253       65     15    173      0  94.0
# 254       35     17    110      1  94.0
# 255       62     14    191      0  93.0
# ...      ...    ...    ...    ...   ...
# 89315      0      0      0      0  88.0
# 89316      0      0      0      0  88.0
# 89317      0      0      0      0  88.0
# 89318      0      0      0      0  89.0
# 89319      0      0      0      0  89.0
#
# [67772 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:57             2        07:10
#        Axis1  Axis2  Axis3  Steps    HR
# 113       77    140     64      1  71.0
# 114       65    137     48      1  73.0
# 115       78     51     34      2  73.0
# 116      138    198     21      0  73.0
# 117       36     50     21      1  73.0
# ...      ...    ...    ...    ...   ...
# 88234      0      0      0      0  74.0
# 88235      0      0      0      0  74.0
# 88236      0      0      0      0  73.0
# 88237      0      0      0      0  74.0
# 88238      0      0      0      0  74.0
#
# [64796 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            1       23:56             1        06:42
#        Axis1  Axis2  Axis3  Steps     HR
# 130       15     84     66      1  228.0
# 131       39    101     81      0  228.0
# 132       55     99     28      0   81.0
# 133       46    103     84      0   86.0
# 134       36     14     24      1  104.0
# ...      ...    ...    ...    ...    ...
# 88562      0      0      0      0   94.0
# 88563      0      0      0      0   94.0
# 88564      0      0      0      0   94.0
# 88565      0      0      0      0   93.0
# 88566      0      0      0      0   93.0
#
# [65054 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       02:27             2        09:02
#        Axis1  Axis2  Axis3  Steps     HR
# 180       38      1     95      0   68.0
# 181       15     11     36      0   67.0
# 182       21     17     63      2   67.0
# 183       39      0     48      0   67.0
# 184       28      0     22      1   67.0
# ...      ...    ...    ...    ...    ...
# 85944      0      0      0      0  122.0
# 85945      0      0      0      0  122.0
# 85946    164     30     59      1  122.0
# 85947    102     26     53      1  122.0
# 85948    168    191     80      1  122.0
#
# [67400 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:28             2        08:02
#        Axis1  Axis2  Axis3  Steps    HR
# 145       49      0     74      0  78.0
# 146      173      8    167      0  77.0
# 147      211     51    276      1  77.0
# 148      107     93     86      1  76.0
# 149      258    151    287      2  75.0
# ...      ...    ...    ...    ...   ...
# 86876      0      0      0      0  88.0
# 86877      0      0      0      0  87.0
# 86878      0      0      0      0  87.0
# 86879      0      0      0      0  87.0
# 86880      0      0      0      0  87.0
#
# [68714 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:17             2        07:13
#        Axis1  Axis2  Axis3  Steps    HR
# 189       37     23     49      0  92.0
# 190        3     24     94      1  90.0
# 191       30      4    120      1  90.0
# 192       33      6    113      1  89.0
# 193       14      1     80      1  88.0
# ...      ...    ...    ...    ...   ...
# 83891      0      0      0      0  72.0
# 83892      0      0      0      0  72.0
# 83893      0      0      0      0  72.0
# 83894      0      0      0      0  72.0
# 83895      0      0      0      0  72.0
#
# [61678 rows x 5 columns]
#    In Bed Date In Bed Time  Out Bed Date Out Bed Time
# 0            2       00:30             2        11:00
#        Axis1  Axis2  Axis3  Steps     HR
# 221       95    124     31      1  126.0
# 222       49     40     16      0  109.0
# 223       44     27     20      0  106.0
# 224        8      2     11      1  101.0
# 225       16     29     16      1   99.0
# ...      ...    ...    ...    ...    ...
# 84083      0      0      0      0   85.0
# 84090      0      0      0      0   90.0
# 84091      0      0      0      0   90.0
# 84092      0      0      0      0   90.0
# 84093      0      0      0      0   90.0
#
# [64121 rows x 5 columns]
# 21

# %%
len(users)
# Out:
# 21

# %% [markdown]
# **Splitting users in training, validation and testing**

# %%
train_users, test_users = train_test_split(users, test_size=0.4, random_state=42)
val_users, test_users = train_test_split(test_users, test_size=0.5, random_state=42)
print('Training users: %s, Validation users: %s, Testing users: %s' % (len(train_users), len(val_users), len(test_users)))
print(train_users)
print(val_users)
print(test_users)
# Out:
# Training users: 12, Validation users: 4, Testing users: 5
# ['user_5', 'user_22', 'user_12', 'user_19', 'user_9', 'user_14', 'user_21', 'user_17', 'user_2', 'user_3', 'user_8', 'user_16']
# ['user_4', 'user_18', 'user_10', 'user_20']
# ['user_13', 'user_6', 'user_15', 'user_1', 'user_7']

# %% [markdown]
# **Visualising data and statistics**

# %%
example = os.path.join(data_dir, train_users[0],'Actigraph.csv')

example = pd.read_csv(example, index_col=0, usecols=[0,1,2,3,4,5])

scatter_matrix(example[example.columns], figsize=(20,10), alpha=0.3)

display(example.corr())
# Out:
#           Axis1     Axis2     Axis3     Steps        HR
# Axis1  1.000000  0.722756  0.697978  0.528078  0.415611
# Axis2  0.722756  1.000000  0.655488  0.515148  0.439305
# Axis3  0.697978  0.655488  1.000000  0.521395  0.419623
# Steps  0.528078  0.515148  0.521395  1.000000  0.416283
# HR     0.415611  0.439305  0.419623  0.416283  1.000000

# %% [markdown]
# **TRANSFORMATIONS**

# %%
class MissingDataValues(BaseEstimator, TransformerMixin):
    def __init__(self,):
        self.column_names=['Axis1','Axis2','Axis3','Steps','HR']
    def fit(self,X,y=None):
        return self
    def transform(self, X):
        missing_index = [i for i in range(X.index.values[0], max(X.index.values)) if i not in X.index.values]
        df_missing = pd.DataFrame(np.nan, index=missing_index, 
                          columns=self.column_names)
        
        df_complete = pd.concat([df_missing, X]).sort_index()
        df_complete.ffill(inplace=True) # Propogate last non-nan observation forward
#         df_complete.bfill(inplace=True) # Backpropagate last non-nan observation (for nan at start)
        return df_complete


# missing_data_values = MissingDataValues()
# df = missing_data_values.fit_transform(x)
# df

# %%
class ComputeSleepLabels(BaseEstimator, TransformerMixin):
    def __init__(self, signal_length, signal_start_timestamp):
        self.signal_length = signal_length
        self.signal_start_timestamp = signal_start_timestamp
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        
        df_labels = pd.DataFrame(np.zeros(shape=(self.signal_length,1)), columns=['Bed Time'])
        
        for index, row in X.iterrows():
            bed_start = str(row['In Bed Date']) + ':' + row['In Bed Time']

            bed_duration = row['Total Minutes in Bed'] * 60

            bed_start_seconds =  datetime.strptime(bed_start, '%d:%H:%M') \
                                - datetime.strptime(self.signal_start_timestamp, '%d:%H:%M:%S')
            bed_start_seconds = int(bed_start_seconds.total_seconds() + 1)

#             print(bed_start_seconds, bed_duration)
            df_labels.iloc[bed_start_seconds:bed_start_seconds+bed_duration, 0] = 1
        
        return df_labels

# %%
class SlidingWindow(BaseEstimator, TransformerMixin):
    def __init__(self,window_size=30, stride_size=15):
        self.window_size = window_size
        self.stride_size = stride_size
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        windows = []
        for i in range(0, X.shape[0]-self.window_size+1, self.stride_size):
            window = X.values[i:i+self.window_size]
            windows.append(window)
        
        windows = np.stack(windows)
        return windows
    
    
# sliding_window = SlidingWindow()
# x = sliding_window.fit_transform(df_train_x)

# %% [markdown]
# **Compute scaler information from training data**

# %%
df_train_x_list = []
for user in train_users:
    print(user)
    df_train_x = os.path.join(data_dir, user,'Actigraph.csv')
    df_train_x = pd.read_csv(df_train_x, index_col=0, usecols=[0,1,2,3,4,5])

    df_train_x = missing_data_values.fit_transform(df_train_x)
    df_train_x = df_train_x.reset_index(drop=True)
    df_train_x_list.append(df_train_x)
    
df_train_x_overall = pd.concat(df_train_x_list)

standard_scaler = StandardScaler()
standard_scaler = standard_scaler.fit(df_train_x_overall)
standard_scaler_scale, standard_scaler_mean, standard_scaler_var = \
standard_scaler.scale_, standard_scaler.mean_, standard_scaler.var_

print(standard_scaler_scale, standard_scaler_mean, standard_scaler_var)

# standard_scaler_scale = np.array([38.98531074, 42.73927114, 40.47020352, 0.44570045, 20.08760831])
# standard_scaler_mean = np.array([16.45840671, 16.26198067, 18.35418061, 0.18630539, 75.20680667])
# standard_scaler_var = np.array([1.51985445e+03, 1.82664530e+03, 1.63783737e+03, 1.98648895e-01, 4.03512008e+02])
# Out:
# user_5
# user_22
# user_12
# user_19
# user_9
# user_14
# user_21
# user_17
# user_2
# user_3
# user_8
# user_16
# [38.98531074 42.73927114 40.47020352  0.44570045 20.08760831] [16.45840671 16.26198067 18.35418061  0.18630539 75.20680667] [1.51985445e+03 1.82664530e+03 1.63783737e+03 1.98648895e-01
#  4.03512008e+02]

# %%
class StandardizeData(BaseEstimator, TransformerMixin):
    def __init__(self, standard_scaler_scale, standard_scaler_mean, standard_scaler_var):
        self.standard_scaler_scale = standard_scaler_scale
        self.standard_scaler_mean = standard_scaler_mean
        self.standard_scaler_var = standard_scaler_var
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        standard_scaler = StandardScaler()
        standard_scaler.scale_ = self.standard_scaler_scale
        standard_scaler.mean_ = self.standard_scaler_mean 
        standard_scaler.var_ = self.standard_scaler_var
        
        X[X.columns] = standard_scaler.transform(X)
        return X

standard_scaler_scale = np.array([38.98531074, 42.73927114, 40.47020352, 0.44570045, 20.08760831])
standard_scaler_mean = np.array([16.45840671, 16.26198067, 18.35418061, 0.18630539, 75.20680667])
standard_scaler_var = np.array([1.51985445e+03, 1.82664530e+03, 1.63783737e+03, 1.98648895e-01, 4.03512008e+02])

# %% [markdown]
# **Pipeline**

# %%
x_pipeline = Pipeline([
    ('missing_data_values', MissingDataValues()),
    ('standardize_data', StandardizeData(standard_scaler_scale, standard_scaler_mean, standard_scaler_var)),
    ('sliding_window', SlidingWindow(window_size=30, stride_size=15)),
])

# %% [markdown]
# **Preprocessing training**

# %%
def preprocess_data(users):
    print(users)
    x_list = []
    y_list = []

    for user in users:
        print(user)

        # x data processing
        df_x = os.path.join(data_dir, user,'Actigraph.csv')
        df_x = pd.read_csv(df_x, index_col=0, usecols=[0,1,2,3,4,5])
        x = x_pipeline.fit_transform(df_x)

        print(x.shape)

        # y labels processing
        # Signal length and starting timestamp
        df_signal = pd.read_csv(os.path.join(data_dir, user, 'Actigraph.csv'), usecols=[0,11,12])
        signal_length = df_signal.iloc[:,0].max() - df_signal.iloc[:,0].min() + 1
        signal_start_timestamp = str(df_signal.iloc[0, 1]) + ':' \
                                + df_signal.iloc[0, 2]

        # Sleep diary (y data)
        df_y = os.path.join(data_dir, user, 'sleep.csv')
        df_y = pd.read_csv(df_y, usecols=[1,2,9])

        y_pipeline = Pipeline([
            ('compute_sleep_labels', ComputeSleepLabels(signal_length = signal_length, signal_start_timestamp = signal_start_timestamp)),
            ('sliding_window', SlidingWindow(window_size=30, stride_size=15)),
        ])

        y = y_pipeline.fit_transform(df_y)


        print(y.shape)


        x_list.append(x)
        y_list.append(y)


    x_overall = np.vstack(x_list)
    y_overall = np.vstack(y_list)

    display(x_overall.shape)
    display(y_overall.shape)
    
    return x_overall, y_overall

train_x, train_y = preprocess_data(train_users)
val_x, val_y = preprocess_data(val_users)
test_x, test_y = preprocess_data(test_users)
# Out:
# ['user_5', 'user_22', 'user_12', 'user_19', 'user_9', 'user_14', 'user_21', 'user_17', 'user_2', 'user_3', 'user_8', 'user_16']
# user_5
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5894, 30, 5)
# (5894, 30, 1)
# user_22
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5626, 30, 5)
# (5626, 30, 1)
# user_12
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5722, 30, 5)
# (5722, 30, 1)
# user_19
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5699, 30, 5)
# (5699, 30, 1)
# user_9
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5590, 30, 5)
# (5590, 30, 1)
# user_14
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5679, 30, 5)
# (5679, 30, 1)
# user_21
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5545, 30, 5)
# (5545, 30, 1)
# user_17
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (6120, 30, 5)
# (6120, 30, 1)
# user_2
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5686, 30, 5)
# (5686, 30, 1)
# user_3
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5936, 30, 5)
# (5936, 30, 1)
# user_8
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5579, 30, 5)
# (5579, 30, 1)
# user_16
# (6144, 30, 5)
# (6144, 30, 1)
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (69220, 30, 5)
# (69220, 30, 1)
# ['user_4', 'user_18', 'user_10', 'user_20']
# user_4
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5874, 30, 5)
# (5874, 30, 1)
# user_18
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5751, 30, 5)
# (5751, 30, 1)
# user_10
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5821, 30, 5)
# (5821, 30, 1)
# user_20
# (5658, 30, 5)
# (5658, 30, 1)
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (23104, 30, 5)
# (23104, 30, 1)
# ['user_13', 'user_6', 'user_15', 'user_1', 'user_7']
# user_13
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5612, 30, 5)
# (5612, 30, 1)
# user_6
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5716, 30, 5)
# (5716, 30, 1)
# user_15
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (6117, 30, 5)
# (6117, 30, 1)
# user_1
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (5659, 30, 5)
# (5659, 30, 1)
# user_7
# (5781, 30, 5)
# (5781, 30, 1)
# C:\Users\Thomas\anaconda3\envs\cerno_project\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# (28885, 30, 5)
# (28885, 30, 1)
